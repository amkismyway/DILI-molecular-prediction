# %% [markdown]
# # 04 — Next steps after core pipeline works
# 1. Add one optional predictor domain at a time.
# 2. Update the codebook before adding any predictor.
# 3. Re-run missingness, descriptive, and modeling checks.
# 4. Do not add race/ethnicity to the primary clinical model until a mentor reviews the scientific rationale.
# 5. Develop weighted descriptive estimates separately from internal model-development metrics.
