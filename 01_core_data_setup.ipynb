# %% [markdown]
# # 01 — Core data setup
# Run the two scripts below. Then inspect the generated dataset and participant flow.

# %%
# !python ../src/download_core_data.py

# %%
# !python ../src/build_core_dataset.py

# %%
import pandas as pd
df = pd.read_csv('../data/processed/core_analytic_dataset.csv')
flow = pd.read_csv('../data/processed/participant_flow.csv')
display(flow)
display(df.head())
df[['mean_sbp','mean_dbp','screen_positive_bp']].describe(include='all')
