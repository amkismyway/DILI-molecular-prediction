# %% [markdown]
# # 03 — Core models
# Baseline model: age, sex, BMI, and waist circumference. Read the protocol before changing features or outcomes.

# %%
# !python ../src/run_core_models.py

# %%
import pandas as pd
results = pd.read_csv('../output/tables/core_model_results.csv', index_col=0)
results.round(3)
